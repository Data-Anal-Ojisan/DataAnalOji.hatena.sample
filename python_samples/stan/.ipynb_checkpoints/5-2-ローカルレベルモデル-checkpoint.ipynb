# %%
import pystan
import numpy as np
import pandas as pd

# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('ggplot')
plt.rcParams["font.family"] = "Meiryo"

# %% [markdown]
# # ホワイトノイズとランダムウォーク
#
# ## 正規ホワイトノイズ

# %%
np.random.seed(1)
wn = np.random.normal(loc=0, scale=1, size=100)

# %% [markdown]
# ## 累積和をとる関数cumsumの説明

# %%
print(np.cumsum([1, 2, 3]))
# Out:
# [1 3 6]

# %% [markdown]
# ## ランダムウォーク

# %%
rw = np.cumsum(wn)

# %% [markdown]
# ## グラフを作る / 2つのグラフをまとめる

# %%
fig = plt.figure()
ax1 = fig.add_subplot(2, 1, 1)
ax2 = fig.add_subplot(2, 1, 2)

ax1.plot(wn)
ax2.plot(rw)

ax1.set_title('ホワイトノイズ')
ax2.set_title('ランダムウォーク')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 複数のホワイトノイズ・ランダムウォーク系列

# %%
wn_mat = np.zeros([100, 20])
rw_mat = np.zeros([100, 20])

# %%
np.random.seed(1)
for i in range(20):
    wn = np.random.normal(loc=0, scale=1, size=100)
    wn_mat[:,i] = wn
    rw_mat[:,i] = np.cumsum(wn)

# %% [markdown]
# ## グラフを作る / 2つのグラフをまとめる

# %%
fig = plt.figure()
ax1 = fig.add_subplot(2, 1, 1)
ax2 = fig.add_subplot(2, 1, 2)

ax1.plot(wn_mat)
ax2.plot(rw_mat)

ax1.set_title('ホワイトノイズ')
ax2.set_title('ランダムウォーク')

plt.tight_layout()
plt.show()

# %% [markdown]
# # データの読み込みとdatetimeへの変換

# %% [markdown]
# ## データの読み込み

# %%
sales_df = pd.read_csv('5-2-1-sales-ts-1.csv')

# %% [markdown]
# ## 日付をdatetime形式にする

# %%
sales_df['date'] = pd.to_datetime(sales_df['date'])

# %% [markdown]
# ## データの先頭行を表示

# %%
sales_df.head(n=3)
# Out:
#         date  sales
# 0 2010-01-01   23.9
# 1 2010-01-02   19.0
# 2 2010-01-03   20.3

# %% [markdown]
# # ローカルレベルモデルの推定

# %% [markdown]
# ## データの準備

# %%
data_list = dict(y=sales_df['sales'], 
                 T=len(sales_df))

# %% [markdown]
# ## モデルの推定

# %%
local_level_stan = pystan.stan(file='5-2-1-local-level.stan',
                               data=data_list,
                               seed=1)
# Out:
# WARNING:pystan:DeprecationWarning: pystan.stan was deprecated in version 2.17 and will be removed in version 3.0. Compile and use a Stan program in separate steps.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_10622bbc8adfbe0e6ce9a8574fb3728b NOW.

# %% [markdown]
# ### stanファイルの内容

# %% [markdown]
# data {
#
#       int T;         // データ取得期間の長さ
#       vector[T] y;   // 観測値
#
# }
#
# parameters {
#
#       vector[T] mu;       // 状態の推定値(水準成分)
#       real<lower=0> s_w;  // 過程誤差の標準偏差
#       real<lower=0> s_v;  // 観測誤差の標準偏差
#
# }
#
# model {
#
#       // 状態方程式に従い、状態が遷移する
#       for(i in 2:T) {
#         mu[i] ~ normal(mu[i-1], s_w);
#
#   }
#
#       // 観測方程式に従い、観測値が得られる
#       for(i in 1:T) {
#         y[i] ~ normal(mu[i], s_v);
#
#   }
# }

# %% [markdown]
# ## 収束の確認

# %%
summary_df = pd.DataFrame(local_level_stan.summary()['summary'],
                          columns=local_level_stan.summary()['summary_colnames'],
                          index=local_level_stan.summary()['summary_rownames'])

plt.figure(figsize=(10, 10))
plt.hlines(y=summary_df['Rhat'].sort_values().index,
           xmin=1,
           xmax=summary_df['Rhat'].sort_values())
plt.vlines(x=1.05, ymin=0, ymax=len(summary_df['Rhat']), linestyles='--')
plt.plot(summary_df['Rhat'].sort_values().values,
         summary_df['Rhat'].sort_values().index,
         marker='.',
         linestyle='None')
plt.yticks(color='None')
plt.tick_params(length=0)
plt.xlabel('Rhat')
plt.show()

# %% [markdown]
# ## 結果の表示

# %%
print(local_level_stan.stansummary(pars=["s_w", "s_v", "lp__"],
                                   probs=[0.025, 0.5, 0.975]))
# Out:
# Inference for Stan model: anon_model_10622bbc8adfbe0e6ce9a8574fb3728b.
# 4 chains, each with iter=2000; warmup=1000; thin=1;
# post-warmup draws per chain=1000, total post-warmup draws=4000.
#
#        mean se_mean     sd   2.5%    50%  97.5%  n_eff   Rhat
# s_w    1.29    0.02    0.3   0.82   1.25   1.98    325   1.01
# s_v    2.88  5.8e-3   0.26   2.39   2.87   3.42   2092    1.0
# lp__ -225.4    1.07  18.33 -261.5 -224.9 -190.3    292   1.01
#
# Samples were drawn using NUTS at Mon Jul 13 10:55:49 2020.
# For each parameter, n_eff is a crude measure of effective sample size,
# and Rhat is the potential scale reduction factor on split chains (at
# convergence, Rhat=1).

# %% [markdown]
# # 結果の図示

# %% [markdown]
# ## 生成された乱数を格納

# %%
mcmc_sample = local_level_stan.extract()

# %% [markdown]
# ## Stanにおける状態を表す変数名

# %%
state_name = 'mu'

# %% [markdown]
# ## 1時点目の状態の95%ベイズ信用区間と中央値を得る

# %%
np.percentile(mcmc_sample[state_name][:,0], q=[2.5, 50, 97.5])
# Out:
# array([18.11574021, 21.48727244, 24.82700243])

# %% [markdown]
# ## すべての時点の状態の、95%ベイズ信用区間と中央値

# %%
result_df = pd.DataFrame(np.zeros([100,3]))
for i in range(len(sales_df)):
    result_df.iloc[i,:] = np.percentile(mcmc_sample[state_name][:,i], q=[2.5, 50, 97.5])

# %% [markdown]
# ## 列名の変更

# %%
result_df.columns = ["lwr", "fit", "upr"]

# %% [markdown]
# ## 時間軸の追加

# %%
result_df['time'] = sales_df['date']

# %% [markdown]
# ## 観測値の追加

# %%
result_df['obs'] = sales_df['sales']

# %% [markdown]
# ## 図示のためのデータ確認

# %%
result_df.head(n=3)
# Out:
#          lwr        fit        upr       time   obs
# 0  18.115740  21.487272  24.827002 2010-01-01  23.9
# 1  18.031008  21.008338  23.943283 2010-01-02  19.0
# 2  18.149184  20.930981  23.751628 2010-01-03  20.3

# %% [markdown]
# ## 図示

# %%
plt.figure(figsize=(15, 5))
plt.plot(result_df['time'],
         result_df['obs'],
         marker='.',
         linewidth=0,
         color='black')
plt.plot(result_df['time'], 
         result_df['fit'], 
         color='black')
plt.fill_between(x=result_df['time'],
                 y1=result_df['upr'],
                 y2=result_df['lwr'],
                 color='gray',
                 alpha=0.5)
plt.xlabel('time')
plt.ylabel('sales')
plt.title('ローカルレベルモデルの推定結果')
plt.show()

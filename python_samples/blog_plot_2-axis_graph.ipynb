# %%
import numpy as np
import pandas as pd 

# %matplotlib inline
import matplotlib.pyplot as plt

# %% [markdown]
# # サンプルデータの作成

# %%
import numpy as np
import pandas as pd

# %matplotlib inline
import matplotlib.pyplot as plt
# plt.style.use("ggplot")

# サンプルデータの生成
N = np.arange(0, 10, 0.01)
Sin = np.sin(N*np.pi) # Sin波
Cos = np.cos(N*np.pi)/200 # Cos波（振幅=1/200）

# %% [markdown]
# # グラフ描画

# %% [markdown]
# ## 1軸グラフ

# %%
# 各線グラフの色を指定
color1 = "b"
color2 = "r"

fig = plt.figure()
ax = fig.add_subplot(1,1,1)
ax.plot(Sin, color=color1, label="Sin")
ax.plot(Cos, color=color2, label="Cos")
ax.legend(loc='upper right')
plt.show()

# %% [markdown]
# ## サブプロットの利用

# %%
fig = plt.figure()
ax1 = fig.add_subplot(2,1,1)
ax2 = fig.add_subplot(2,1,2)

ax1.plot(Sin, color=color1, label="Sin")
ax2.plot(Cos, color=color2, label="Cos")
ax1.legend(loc='upper right')
ax2.legend(loc='upper right')
plt.show()

# %% [markdown]
# ## 2軸

# %%
# 2軸
fig = plt.figure()
ax1 = fig.add_subplot(1,1,1)
ax2 = ax1.twinx()


ax1.plot(Sin, color=color1, label="Sin")
ax2.plot(Cos, color=color2, label="Cos")
# 凡例
# グラフの本体設定時に、ラベルを手動で設定する必要があるのは、barplotのみ。plotは自動で設定される＞
handler1, label1 = ax1.get_legend_handles_labels()
handler2, label2 = ax2.get_legend_handles_labels()
# 凡例をまとめて出力する
ax1.legend(handler1 + handler2, label1 + label2, loc='upper right', borderaxespad=0,)
 
ax2.spines['left'].set_color(color1)
ax2.spines['right'].set_color(color2)
# 軸の縦線の色を変更している
ax1.tick_params(axis='y', colors=color1)
ax2.tick_params(axis='y', colors=color2)
